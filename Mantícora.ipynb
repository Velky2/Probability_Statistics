# %% [markdown]
# # Exercício 4
# ### 🦁 Mantícora

# %% [markdown]
# 1. Qual a probabilidade de sortear 2 cartas vermelhas em um baralho convencional (52 cartas)?
#
#    Podemos sortear (52!)/(50! * 2!) cartas. Existem 26 cartas vermelhas, então podemos sortear 26!/(2! * 24!) cartas.
#
#    Logo, a probabilidade é de (50! * 2! * 26!)/(52! * 24! * 2!) = (26 * 25)/(52 * 51) = 25/102
#
#    Portanto, temos uma chance considerável, aproximadamente 1/4, não sendo um evento muito raro. Isso faz sentido, já que metade das cartas são vermelhas.

# %% [markdown]
# 2. Qual a probabilidade de sortear 5 cartas do mesmo naipe em um baralho convencional?
#
#    Podemos sortear 52!/(5! * 47!). Para ser do mesmo naipe, podemos sortear 4 * (13!)(5! * 8!).
#
#    Logo, a probabilidade é de (4 * 13! * 47! * 5!)/(5! * 8! * 52!) = (4 * 13 * 12 * 11 * 10 * 9)/(52 * 51 * 50 * 49 * 48) =~ 1.98e-3
#
#    Portanto, é um evento bem raro, o que faz sentido já que temos de sortear 5 vezes sem reposição dentre 13 cartas entre 52.

# %% [markdown]
# 3. Qual a probabilidade de se ganhar na loteria federal comprando apenas um bilhete de 6 números? A loteria federal sorteia 6 números inteiros no intervalo [1, 60]. Um bilhete de 6 números ter permite escolher 6 números diferentes dentro do intervalo. Ganhar, neste caso, significa que você acertou os 6 números sorteados.
#
#    O resultado é 60 escolhe 6: 60!/6!54!. Porém, podemos escolher somente uma das combinações.
#
#    Assim, a probabilidade é de 54!6!/60! = 6 * 5 * 4 * 3 * 2/60 * 59 * 58 * 57 * 56 * 55 = 1/50063860 =~ 1.99e-8
#
#    Logo, apostar na loteria é jogar dinheiro no lixo, pois a chance de ganhar é desprezível.

# %% [markdown]
# 4. Existem 23 pessoas em uma sala. Qual é a probabilidade de que existam pelo menos duas pessoas que façam aniversário no mesmo dia dentro desta sala?
#    É difícil fazer esse problema, pois a solução intuitiva é usar teoria dos conjuntos para resolver (inclusão-exclusão):
#    $$
# {23\choose 2}{1/365} - {23\choose 3}{1/365^2}+....
#    $$
#    Porém, essa conta é muito difícil, assim, podemos calcular os eventos desfavoráveis, mais fácil.
#    $$
#    {365\choose 23} * 23!
#    $$
#    Logo, a probailidade de não terem 2 pessoas fazendo aniversário no mesmo dia é 365 escolhe 23 * 23!/(365^23).
#    Computacionalmente, o resultado é aproximadamente 49%. Logo, a probabilidade de ao menos duas pessoas fazerem aniversário no mesmo dia é 51%.
#
#    Portanto, o resultado desse clássico problema é bem interessante, pois com apenas 23 pessoas, é mais provável que duas pessoas façam aniversário no mesmo dia que não, apesar de terem 365 dias.

# %% [markdown]
# 5. Uma rifa tem 100 números e 3 prêmios. Qual a probabilidade de você ganhar ao menos um prêmio se você comprar 5 números?
#    As possibilidades totais de escolher bilhetes é $$ {100\choose 5} $$
#    As possibilidades de escolher bilhetes errados é $$ {97\choose 5} $$
#    Logo, a probabilidade de perder é 97!5!95!/100!5!92! = 95*94*93/100*99*98 =~ 0.856.
#    Assim, a probabilidade de ganhar é 0.144.
#    Portanto, com 5% das rifas, tendo três prêmios você tem 14.4% de chance de ganhar.
#
#    É interessante notar que multiplicar o nùmero de casas certas não multiplica pelo mesmo valor sua chance de ganhar para todos os valores (exceção óbvia de 0).
