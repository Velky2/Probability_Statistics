# %% [markdown]
# # Exercício 4
# ### 🗿 Gárgula

# %% [markdown]
# 1. Um casal tem dois filhos. Qual a probabilidade dos dois filhos serem meninas?
#
#    A probabilidade de um filho ser menina é 0.5, pois tem a mesma probabilidade de ser menino ou menina.
#
#    Temos 2 * 2 possibilidades e 1 favorável. A probabilidade é de 1/4.
#
#    Logo, é um evento não muito raro.

# %% [markdown]
# 2. Um casal tem dois filhos. Qual a probabilidade dos dois filhos serem meninas se um dos filhos é uma menina?
#
#    Existem 3 possibilidades (menina menino, menino menina, menina menina).
#    Logo, a probabilidade é de 1/3.
#
#    Portanto, é interessante notar que a probabilidade intuitiva (1/2) é muito maior que a probabilidade real.

# %% [markdown]
# 3. Ao rolar um dado de 6 faces, qual a probabilidade de sair o número 5?
#
#    P(t) = P(1) = 1/6
#
#    Portanto, todos os números tem a mesma probabilidade de sair de 1/6.

# %% [markdown]
# 4. Ao rolar dois dados de 6 faces, qual é a probabilidade de sair duas faces com o número 1?
#
#    P(t) = P(1) * P(2) = 1/6 * 1/6 = 1/36
#
#    Portanto, a probabilidade é, bem pequena, justificando o 12 do Catan ser minúsculo.

# %% [markdown]
# 5. Ao rolar dois dados de 6 faces, qual a probabilidade de as duas faces serem iguais?
#
#    Temos 6 possiblidades de serem iguais e 36 (6*6) possibilidades de faces. Assim, a probabilidade de serem iguais é de 6/36 = 1/6.
#
#    Portanto, é interessante ver que um dado tem 1/6 de chance de cada face e dois dados tem 1/6 de terem duas faces iguais.
